# %% [markdown]
# ## plt and seaborn Exercices

# %%
## list all datasets within seaborn

import seaborn as sns
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
data = sns.load_dataset('mpg')  #exercise, flights, healthexp, taxis
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# # Ex 1:
#
# 1. Charger l'ensemble de données 'mpg'
#
# 3. Visualiser la distribution des poids des voitures.
# 4. Explorer la relation entre l'accélération des voitures et le poids.
# 5. Afficher le nombre de voitures par origine.

# %%
import seaborn as sns
import pandas as pd

# Load the dataset into a pandas DataFrame
data = sns.load_dataset('mpg')
df = pd.DataFrame(data)
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
sns.histplot(data.weight)
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %%
sns.scatterplot(x='weight',y='acceleration',color='black',data=data)
# Out:
# <Axes: xlabel='weight', ylabel='acceleration'>

# %%
# data.corr()

# %%
sns.countplot(x='origin',data=data)
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
# Import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset into a pandas DataFrame
data = sns.load_dataset('mpg')
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# Tâche 2

# Check for missing values
missing_values = data.isna().sum()
missing_values
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
nans = data[data.isna().any(axis=1)].index     #any(axis=1) : check for the condition across all columns for each row
print(nans)
# Out:
# Index([32, 126, 330, 336, 354, 374], dtype='int64')

# %%
data.iloc[32]    #NaN  : not a number = missing value
# Out:
# mpg                   25.0
# cylinders                4
# displacement          98.0
# horsepower             NaN
# weight                2046
# acceleration          19.0
# model_year              71
# origin                 usa
# name            ford pinto
# Name: 32, dtype: object

# %%
# data types
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
# None

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Tâche 3
plt.figure(figsize=(8, 6))
sns.histplot(x='weight', data=data)

#ou
# plt.hist(data['weight'], bins=20) #, color='skyblue')

plt.xlabel('Weight')
plt.ylabel('Count')
plt.title('Distribution of Car weights')
plt.show()

# %%
# Tâche 4
plt.figure(figsize=(8, 6))
sns.scatterplot(x='weight', y='acceleration', data=data, color='green')
plt.xlabel('weight')
plt.ylabel('acceleration')
plt.title('Relationship')
plt.show()

# %%
# tache 5
origin_counts = data.groupby('origin').size()   #.reset_index(name='count')
print(origin_counts)
# Out:
# origin
# europe     70
# japan      79
# usa       249
# dtype: int64

# %%
print(origin_counts.index)
print(origin_counts.values)
# Out:
# Index(['europe', 'japan', 'usa'], dtype='object', name='origin')
# [ 70  79 249]

# %%
# ou
L = list(data['origin'])
H = set(L)
H
# Out:
# {'europe', 'japan', 'usa'}

# %%
G = []
for i in H:
    s = L.count(i)
    G.append(s)
    
G
# Out:
# [79, 249, 70]

# %%
# ou
origin_counts = data['origin'].value_counts()
origin_counts
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
origin_counts.iloc[0]  #ou loc['usa']
# Out:
# 249

# %%
print(origin_counts.index)
print(origin_counts.values)
# Out:
# Index(['usa', 'japan', 'europe'], dtype='object', name='origin')
# [249  79  70]

# %%
sns.barplot(x=origin_counts.index, y=origin_counts.values)
# Out:
# <Axes: xlabel='origin'>

# %%
## Ou
# Tâche 5
plt.figure(figsize=(8, 6))
sns.countplot(x='origin', data=data, palette='Set2')
plt.xlabel('origin')
plt.ylabel('Count')
plt.title('Count of Cars by origin')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Ex 2 -------------------------------------------------------------

# %% [markdown]
# **Tâches:**
#
# 1. Chargez l'ensemble de données du **titanic** dans un DataFrame pandas.
#
# 2. Effectuez le prétraitement des données :
#    - Gérez les valeurs manquantes (par exemple, remplissez les valeurs manquantes de l'âge avec l'âge médian).
#    - Créez une nouvelle colonne appelée "Groupe d'âge" en catégorisant les passagers en groupes d'âge (par exemple, enfant, jeune adulte, adulte, senior).
#    - Créez une nouvelle colonne appelée "Taille de la famille" en combinant les colonnes:
#        - "SibSp" veut dire:  Siblings: brothers, sisters, husbands, or wives
#        - "Parch" veut dire:  parents or children
#
# 3. Explorez les données :
#    - Visualisez la distribution des âges des passagers.
#    - Montrer le nombre de passagers dans chaque classe.
#    - Visualiser la corrélation entre différentes caractéristiques numériques (par exemple, l'âge, le tarif).
#
# 4. Analysez les taux de survie :
#    - Calculez le taux de survie global.
#    - Montrer les taux de survie par genre.
#    - Montrer les taux de survie par classe de passager.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
titanic = sns.load_dataset('titanic') 
dt = pd.DataFrame(titanic)
print(dt)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
median_age = dt['age'].median()
dt['age'].fillna(median_age)
print(dt)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
def categorie_age(age):
    if age < 13:
        return 'Enfant'
    elif age < 18:
        return 'Adolescent'
    elif age < 36:
        return 'Jeune Adulte'
    elif age < 61:
        return 'Adulte'
    else:
        return 'Senior'
    
dt['Groupe d\'âge'] = dt['age'].apply(categorie_age)
print(dt)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Groupe d'âge
# 0      man        True  NaN  Southampton    no  False  Jeune Adulte
# 1    woman       False    C    Cherbourg   yes  False        Adulte
# 2    woman       False  NaN  Southampton   yes   True  Jeune Adulte
# 3    woman       False    C  Southampton   yes  False  Jeune Adulte
# 4      man        True  NaN  Southampton    no   True  Jeune Adulte
# ..     ...         ...  ...          ...   ...    ...           ...
# 886    man        True  NaN  Southampton    no   True  Jeune Adulte
# 887  woman       False    B  Southampton   yes   True  Jeune Adulte
# 888  woman       False  NaN  Southampton    no  False  Jeune Adulte
# 889    man        True    C    Cherbourg   yes   True  Jeune Adulte
# 890    man        True  NaN   Queenstown    no   True  Jeune Adulte
#
# [891 rows x 16 columns]

# %%
dt['Taille de la famille'] = dt['sibsp'] + dt['parch']
print(dt['Taille de la famille'])
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Name: Taille de la famille, Length: 891, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(dt['age'])
plt.title("Distribution des âges des passagers")
plt.xlabel("age")
plt.ylabel("Nombre de passagers")
plt.show()

# %%
sns.countplot(x='pclass', data=dt, palette="viridis") 
plt.title("Nombre de passagers par classe")
plt.xlabel("classe")
plt.ylabel("Nombre de passagers")
plt.show()
# Out:
# C:\Users\ayman\AppData\Local\Temp\ipykernel_27708\3878304897.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='pclass', data=dt, palette="viridis")

# %%
dt_corr = dt.select_dtypes(include=['number']).corr()
sns.heatmap(dt_corr)
plt.title("Matrice de corrélation")
plt.show()

# %%
taux_survie = dt['survived'].mean() * 100
plt.bar(['Taux de Survie Global'], [taux_survie])
plt.ylabel('Taux de Survie (%)')
plt.ylim(0, 100)
# Out:
# (0.0, 100.0)

# %%
taux_survieGenre = dt.groupby('sex')['survived'].mean() * 100
sns.barplot(x=taux_survieGenre.index, y=taux_survieGenre.values)
plt.ylim(0, 100)
plt.show()

# %%
taux_survieClass = dt.groupby('pclass')['survived'].mean() * 100
sns.barplot(x=taux_survieClass.index, y=taux_survieClass.values)
plt.ylim(0, 100)
plt.show()

# %% [markdown]
# # Ex 3 ------------------------------------------------------------

# %% [markdown]
# **Tâches:**
#
# 1. Chargez l'ensemble de données "tips" depuis Seaborn dans un DataFrame pandas.
#
# 2. Effectuez la prétraitement des données :
#    - Calculez le pourcentage de pourboire pour chaque addition (montant du pourboire / total de l'addition).
#    - Créez une nouvelle colonne qui catégorise les clients comme "généreux" ou "peu généreux" en fonction d'un seuil de pourcentage de pourboire (par exemple, >= 15 % est généreux).
#
# 3. Analysez et visualisez les données :
#    - Calculez et visualisez le pourcentage moyen de pourboire par jour de la semaine à l'aide de Seaborn, avec des couleurs différentes pour les clients "généreux" et "peu généreux" (utilisez le paramètre "hue").
#    - Calculez et visualisez les montants totaux de l'addition par jour de la semaine à l'aide de Seaborn, avec des couleurs différentes pour les clients "généreux" et "peu généreux" (utilisez le paramètre "hue").
#    - Déterminez quel jour de la semaine a le pourcentage moyen de pourboire le plus élevé pour les clients "généreux" et visualisez-le.
#
# * Cet exercice implique le prétraitement de l'ensemble de données "tips", la visualisation du pourcentage moyen de pourboire et du montant total de l'addition par jour de la semaine, ainsi que l'identification du jour de la semaine avec le pourcentage moyen de pourboire le plus élevé pour les clients "généreux". Ajustez la variable "tip_threshold" au besoin pour définir les clients "généreux" en fonction de vos critères.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips') 
dt = pd.DataFrame(tips)
print(dt)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dt['Tpercentage'] = (dt['tip'] / dt['total_bill']) * 100   
dt['generosite'] = np.where(dt['Tpercentage'] >= 15, 'généreux', 'peu généreux')
print(dt)
# Out:
#      total_bill   tip     sex smoker   day    time  size  Tpercentage  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2     5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3    16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2    13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4    14.680765
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2     9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2    15.974441
#
#        generosite
# 0    peu généreux
# 1        généreux
# 2        généreux
# 3    peu généreux
# 4    peu généreux
# ..            ...
# 239      généreux
# 240  peu généreux
# 241  peu généreux
# 242  peu généreux
# 243      généreux
#
# [244 rows x 9 columns]

# %%
moyenneGenerosite = dt.groupby(['day', 'generosite'], observed=False)['Tpercentage'].mean().reset_index()
sns.barplot(data=moyenneGenerosite, x='day', y='Tpercentage', hue='generosite', palette='Set2')
plt.ylabel("Pourcentage de pourboire")
plt.xlabel("Jour de la semaine")
plt.show()

# %%
totalParJour = dt.groupby(['day', 'generosite'],observed=False)['total_bill'].sum().reset_index()
sns.barplot(data=totalParJour, x='day', y='total_bill', hue='generosite')
plt.ylabel("Montant total")
plt.xlabel("Jour de la semaine")
plt.show()

# %%
avg_tip_generous = dt[dt['generosite'] == 'généreux'].groupby('day',observed=False)['Tpercentage'].mean().reset_index()
highest_tip_day = avg_tip_generous.loc[avg_tip_generous['Tpercentage'].idxmax(), 'day']
print("Le jour avec le pourcentage le plus élevé est :" , highest_tip_day)
sns.barplot(data=avg_tip_generous, x='day', y='Tpercentage')
plt.ylabel("Pourcentage de pourboire")
plt.xlabel("Jour de la semaine")
plt.show()
# Out:
# Le jour avec le pourcentage le plus élevé est : Sun

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
taxis = sns.load_dataset('taxis')
dt = pd.DataFrame(taxis)
print(dt)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 14 columns]

# %%
PassagerDominant = dt["passengers"].max()
print(PassagerDominant)
# Out:
# 6

# %%
# plt.figure(figsize=(10, 6))
# sns.lineplot(x='fare', y='total', data=dt.c, marker='o', color='b', label='Value')
# plt.xlabel('fare')
# plt.ylabel('total')
dt_corr = dt.select_dtypes(include=['number']).corr()
sns.heatmap(dt_corr)
plt.title("Matrice de corrélation")
plt.show()

# %%
sns.countplot( x='pickup_borough', data=dt)
# Out:
# <Axes: xlabel='pickup_borough', ylabel='count'>
